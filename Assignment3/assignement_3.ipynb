# %% [markdown]
# # Different Visualisation on iris dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print("First 5 rows of the iris dataset:")
print(df.head())
# Out:
# First 5 rows of the iris dataset:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print("Any null/missing values? ")
print(df.isnull().sum())
# Out:
# Any null/missing values?
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
print("Dataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %% [markdown]
# #  Line Graph (Sepal Length over Samples)

# %% [markdown]
# The line graph shows how Sepal Length varies across all 150 iris samples. The pattern appears smooth overall, with noticeable fluctuations between samples of different species.

# %%
plt.figure(figsize=(10, 5))
plt.plot(df.index, df['SepalLengthCm'], color='blue', marker='o')
plt.title('Sepal Length Across Samples')
plt.xlabel('Sample Index')
plt.ylabel('Sepal Length (cm)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Histogram (Petal Width Distribution)

# %% [markdown]
# The histogram reveals that most flowers have a Petal Width between 0.1 cm and 0.5 cm. The data is not uniformly distributed, indicating some species have much thicker petals than others.

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['PetalWidthCm'], bins=15, color='green', edgecolor='black')
plt.title('Distribution of Petal Width')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Pie Chart (Species Count)

# %% [markdown]
# All three species—Setosa, Versicolor, and Virginica—are equally represented in the dataset, each comprising 33.3% of the total samples (50 each out of 150).

# %%
species_counts = df['Species'].value_counts()
plt.figure(figsize=(9, 9))
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Iris Species')
plt.show()

# %% [markdown]
# # Box & Whisker Plot (Sepal Width by Species)

# %% [markdown]
# Petal Length and Petal Width show a strong positive correlation (~0.96), meaning as one increases, so does the other. Sepal Length also shows moderate correlation with petal features, while Sepal Width has a weaker relationship.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Species', y='SepalWidthCm', data=df, palette='pastel')
plt.title('Sepal Width Distribution by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Width (cm)')
plt.show()
# Out:
# C:\Users\sidha\AppData\Local\Temp\ipykernel_11556\474244604.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Species', y='SepalWidthCm', data=df, palette='pastel')

# %% [markdown]
# # Heatmap (Correlation Matrix)

# %%
plt.figure(figsize=(8, 6))
corr_matrix = df.drop('Species', axis=1).corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Feature Correlation Heatmap')
plt.show()

# %% [markdown]
# # conclusion

# %%
print("Visualized line trends, distributions, species count, and correlations.")
print("Matplotlib, Pandas and Seaborn were used mostly")
# Out:
# Visualized line trends, distributions, species count, and correlations.
# Matplotlib, Pandas and Seaborn were used mostly
